# %% [markdown]
# #ASSINGMENT_2
# **Q1 What are the two values of the Boolean data type? How do you write them?**
#
# <br>1) True
# <br>2) False
#
# **Q2 What are the three different types of Boolean operators?**
#
# <br>1) and
# <br>2) or
# <br>3) not
#
# **Q3 Make a list of each Boolean operator&#39;s truth tables (i.e. every possible combination of Boolean
# values for the operator and what it evaluate ).**
#
# <br>1) and
# <br>2) or
# <br>3) not
#
# <table>
# <caption>AND TABLE</CAPTION>
# <tr>
# <td>A</td>
# <td>B</td>
# <td>RESULT</td>
# </tr>
# <tr>
# <td>TRUE</td>
# <td>TRUE</td>
# <td>TRUE</td>
# </tr>
# <tr>
# <td>TRUE</td>
# <td>FALSE</td>
# <td>FALSE</td>
# </tr>
# <tr>
# <td>FALSE</td>
# <td>TRUE</td>
# <td>FALSE</td>
# </tr>
# <tr>
# <td>FALSE</td>
# <td>FALSE</td>
# <td>FALSE</td>
# </tr>
# </table>
#
# <table>
# <caption>OR TABLE</CAPTION>
# <tr>
# <td>A</td>
# <td>B</td>
# <td>RESULT</td>
# </tr>
# <tr>
# <td>TRUE</td>
# <td>TRUE</td>
# <td>TRUE</td>
# </tr>
# <tr>
# <td>TRUE</td>
# <td>FALSE</td>
# <td>TRUE</td>
# </tr>
# <tr>
# <td>FALSE</td>
# <td>TRUE</td>
# <td>TRUE</td>
# </tr>
# <tr>
# <td>FALSE</td>
# <td>FALSE</td>
# <td>FALSE</td>
# </tr>
# </table>
#
# <table>
# <caption>NOT TABLE</CAPTION>
# <tr>
# <td>A</td>
# <td>RESULT</td>
# </tr>
# <tr>
# <td>TRUE</td>
# <td>FALSE</td>
# </tr>
#
# <tr>
# <td>FALSE</td>
# <td>TRUE</td>
# </tr>
# </table>
#
# **Q4 What are the values of the following expressions?**
#
# <br>1) (5 &gt; 4) and (3 == 5) --> False
# <br>2) not (5 &gt; 4) --> False
# <br>3) not ((5 &gt; 4) or (3 == 5)) --> True
# <br>4) (True and True) and (True == False) --> False
# <br>4) (True and True) and (True == False) --> False
# <br>5) (not False) or (not True) --> True
#
# **Q5 What are the six comparison operators?**
#
# <br>1) Less than ( < )
# <br>2) Less than or equal to (<=)
# <br>3) Greater than (>)
# <br>4) Greater than or equal to (>=)
# <br>5) Equal to ( == )
# <br>6) Not equal to ( != )
#
# **Q6 How do you tell the difference between the equal to and assignment operators? Describe a
# condition and when you would use one.**
#
# <br>1) The “=” is an assignment operator is used to assign the value on the right to the variable on the left.
# e.g.,
# a = 10 --> it stores value in variable a
#
# <br>2) The ‘==’ operator checks whether the two given operands are equal or not. If so, it returns true. Otherwise it returns false.
# e.g.,
# 5 == 5 --> it will result true.
#
# **Q7 Identify the three blocks in this code:**
#
# spam = 0 <br>
# if spam == 10: <br>
# print(&#39;eggs&#39;) <br>
# if spam &gt; 5:<br>
# print(&#39;bacon&#39;)<br>
# else:<br>
# print(&#39;ham&#39;)<br>
# print(&#39;spam&#39;)<br>
# print(&#39;spam&#39;)<br>
#
# <br>1) ham spam spam
#
# **Q8 Write code that prints Hello if 1 is stored in spam, prints Howdy if 2 is stored in spam, and prints
# Greetings! if anything else is stored in spam**
#
# <pre>
# spam = 10;
# if spam ==1 :
#   print("Hello")
# elif spam == 2 :
#   print("howdy")
# else :
#   print("Greetings!")
# </pre>
#
# **Q9 If your programme is stuck in an endless loop, what keys you’ll press?**
#
# <br>1) ctrl + c
#
#
# **Q10 How can you tell the difference between break and continue?**
#
# <br>1) The Python break statement stops the loop in which the statement is placed. A Python continue statement skips a single iteration in a loop.
#
# **Q11 In a for loop, what is the difference between range(10), range(0, 10), and range(0, 10, 1)?**
#
# <br>1) range(10) --> results 0 - 10 {default start is '0'}
# <br>2) range(0, 10) --> results 0 - 10 {start is inclusive '0', end is exclusive '10' }
# <br>3) range(0, 10, 1) --> results 0 - 10 {start is inclusive '0', end is exclusive '10', increment value is '1'}
#
# **Q12 Write a short program that prints the numbers 1 to 10 using a for loop. Then write an equivalent
# program that prints the numbers 1 to 10 using a while loop.**
#
# <pre>
# #for loop
# for i in range(1,11):
#   print(i)
#
# #while loop
# i = 1
# while i < 11:
#  print(i)
#  i+=
# </pre>
#
# **Q13 If you had a function named bacon() inside a module named spam, how would you call it after
# importing spam?**
#
# <br>1) from spam import bacon
